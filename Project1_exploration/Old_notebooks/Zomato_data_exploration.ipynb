# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import gmaps
import json
from pprint import pprint
from pyzomato import Pyzomato

# Zomato API Key
from config import z_key

# %%
p = Pyzomato(z_key)

# set up other lists to hold data info
restaurant_name = []
restaurant_id = []
restaurant_address = []
restaurant_locality = []
restaurant_city = []
latitude = []
longitude = []
zip_code = []
cuisines = []
price_range = []
average_cost_for_two = []
user_rating = []
rating_text = []
votes = []
all_reviews_count = []

#Set up a dataframe with the latitude and longitude of the five cities we are interested in:

#cities = pd.DataFrame({
   # "city" : ['Sydney',"Melbourne",'Brisbane','Perth','Adelaide'],
   # "entity_ID" : ["260", "259", "298", "296", "297"]
   # })
 # 'lat' : ["-33.8688", "-37.8136", "-27.4698", "-31.9505", "-34.9285"],
 #  'lon' : ["151.2094", "144.9631","153.0251", "115.8605", "138.6007"]


#Data for 100 top restaurants in Sydney - Category =10  - dinner:
#for row in cities["city"]:
 #   ID=cities["entity_ID"].astype(int)
    
# Create a loop that iterates five times starting from 0th record and increases by increments of 20
for a in range(0,100,20):
    response = p.search(lat="-33.8688",lon="151.2094",
                           count=20,
                           sort='rating',
                           order='desc',
                           category=(10),
                           start=a)
    for i in range(0,20,1):
        try:
            restaurant_id.append(response["restaurants"][i]["restaurant"]['id'])
            restaurant_name.append(response["restaurants"][i]["restaurant"]['name'])
            restaurant_locality.append(response["restaurants"][i]["restaurant"]["location"]["locality"])
            restaurant_address.append(response["restaurants"][i]["restaurant"]["location"]["address"])
            restaurant_city.append(response["restaurants"][i]["restaurant"]["location"]["city"])
            latitude.append(response["restaurants"][i]["restaurant"]["location"]["latitude"])
            longitude.append(response["restaurants"][i]["restaurant"]["location"]["longitude"])
            zip_code.append(response["restaurants"][i]["restaurant"]["location"]["zipcode"])
            cuisines.append(response["restaurants"][i]["restaurant"]['cuisines'])
            price_range.append(response["restaurants"][i]["restaurant"]['price_range'])
            average_cost_for_two.append(response["restaurants"][i]["restaurant"]['average_cost_for_two'])
            user_rating.append(response["restaurants"][i]["restaurant"]["user_rating"]['aggregate_rating'])
            rating_text.append(response["restaurants"][i]["restaurant"]["user_rating"]['rating_text'])
            votes.append(response["restaurants"][i]["restaurant"]["user_rating"]['votes'])
            all_reviews_count.append(response["restaurants"][i]["restaurant"]["all_reviews_count"])
        except KeyError:
            print(f"restaurant not found! Skipping")
            pass
    
print("---------------------------")
print("Data Retrieval Complete")
# Out:
# ---------------------------
# Data Retrieval Complete

# %%
#Convert Raw data to DataFrame
sydney_df = pd.DataFrame({
    'Restaurant_id': restaurant_id,
    'Name': restaurant_name,
    'Locality':restaurant_locality,
    'Address':restaurant_address,
    'City': restaurant_city,
    'Latitude': latitude,
    'Longitude': longitude,
    'Zip Code': zip_code,
   'Cuisines' : cuisines,
    'Price Range' :price_range,
    'Average Cost for two' :average_cost_for_two,
    'User Rating' : user_rating,
    'Rating Text' : rating_text,
    "Votes" : votes,
    "all_reviews_count": all_reviews_count
})

#Exporting the DataFrame into a csv
sydney_df.to_csv('output_data/restaurants_category_10_sydney.csv')
sydney_df.count()
# Out:
# Restaurant_id           100
# Name                    100
# Locality                100
# Address                 100
# City                    100
# Latitude                100
# Longitude               100
# Zip Code                100
# Cuisines                100
# Price Range             100
# Average Cost for two    100
# User Rating             100
# Rating Text             100
# Votes                   100
# all_reviews_count       100
# dtype: int64

# %%
#As Zomato API has a limitation of 100 restaurants per call, we couldn't create a loop for the five cities.
#Unfortunately we have to repeat our code five times to generate five different dataframes.

p = Pyzomato(z_key)

# set up other lists to hold data info
restaurant_name = []
restaurant_id = []
restaurant_address = []
restaurant_locality = []
restaurant_city = []
latitude = []
longitude = []
zip_code = []
cuisines = []
price_range = []
average_cost_for_two = []
user_rating = []
rating_text = []
votes = []
all_reviews_count = []

#Set up a dictionary with the latitude and longitude of the five cities we are interested in:
#cities = {
 #   "city" : ['Sydney',"Melbourne",'Brisbane','Perth','Adelaide'],
 #   'lat' : ["-33.8688", "-37.8136", "-27.4698", "-31.9505", "-34.9285"],
 #   'lon' : ["151.2094", "144.9631","153.0251", "115.8605", "138.6007"] 
#}

#Data for 100 top restaurants in Melbourne - Category =10  - dinner:

# Create a loop that iterates five times starting from 0th record and increases by increments of 20
for a in range(0,100,20):
    response = p.search(lat="-37.8136",lon="144.9631",
                           count=20,
                           sort='rating',
                           order='desc',
                           category=(10),
                           start=a)
    for i in range(0,20,1):
        try:
            restaurant_id.append(response["restaurants"][i]["restaurant"]['id'])
            restaurant_name.append(response["restaurants"][i]["restaurant"]['name'])
            restaurant_locality.append(response["restaurants"][i]["restaurant"]["location"]["locality"])
            restaurant_address.append(response["restaurants"][i]["restaurant"]["location"]["address"])
            restaurant_city.append(response["restaurants"][i]["restaurant"]["location"]["city"])
            latitude.append(response["restaurants"][i]["restaurant"]["location"]["latitude"])
            longitude.append(response["restaurants"][i]["restaurant"]["location"]["longitude"])
            zip_code.append(response["restaurants"][i]["restaurant"]["location"]["zipcode"])
            cuisines.append(response["restaurants"][i]["restaurant"]['cuisines'])
            price_range.append(response["restaurants"][i]["restaurant"]['price_range'])
            average_cost_for_two.append(response["restaurants"][i]["restaurant"]['average_cost_for_two'])
            user_rating.append(response["restaurants"][i]["restaurant"]["user_rating"]['aggregate_rating'])
            rating_text.append(response["restaurants"][i]["restaurant"]["user_rating"]['rating_text'])
            votes.append(response["restaurants"][i]["restaurant"]["user_rating"]['votes'])
            all_reviews_count.append(response["restaurants"][i]["restaurant"]["all_reviews_count"])
        except KeyError:
            print(f"restaurant not found! Skipping")
            pass
    
print("---------------------------")
print("Data Retrieval Complete")

#Convert Raw data to DataFrame

melbourne_df = pd.DataFrame({
    'Restaurant_id': restaurant_id,
    'Name': restaurant_name,
    'Locality':restaurant_locality,
    'Address':restaurant_address,
    'City': restaurant_city,
    'Latitude': latitude,
    'Longitude': longitude,
    'Zip Code': zip_code,
   'Cuisines' : cuisines,
    'Price Range' :price_range,
    'Average Cost for two' :average_cost_for_two,
    'User Rating' : user_rating,
    'Rating Text' : rating_text,
    "Votes" : votes,
    "all_reviews_count": all_reviews_count
})


#Exporting the DataFrame into a csv
melbourne_df.to_csv('output_data/restaurants_category_10_melbourne.csv')
# Out:
# ---------------------------
# Data Retrieval Complete

# %%
#Brisbane data

p = Pyzomato(z_key)

# set up other lists to hold data info
restaurant_name = []
restaurant_id = []
restaurant_address = []
restaurant_locality = []
restaurant_city = []
latitude = []
longitude = []
zip_code = []
cuisines = []
price_range = []
average_cost_for_two = []
user_rating = []
rating_text = []
votes = []
all_reviews_count = []

#Set up a dictionary with the latitude and longitude of the five cities we are interested in:
#cities = {
 #   "city" : ['Sydney',"Melbourne",'Brisbane','Perth','Adelaide'],
 #   'lat' : ["-33.8688", "-37.8136", "-27.4698", "-31.9505", "-34.9285"],
 #   'lon' : ["151.2094", "144.9631","153.0251", "115.8605", "138.6007"] 
#}

#Data for 100 top restaurants in Brisbane - Category =10  - dinner:

# Create a loop that iterates five times starting from 0th record and increases by increments of 20
for a in range(0,100,20):
    response = p.search(lat="-27.4698",lon="153.0251",
                           count=20,
                           sort='rating',
                           order='desc',
                           category=(10),
                           start=a)
    for i in range(0,20,1):
        try:
            restaurant_id.append(response["restaurants"][i]["restaurant"]['id'])
            restaurant_name.append(response["restaurants"][i]["restaurant"]['name'])
            restaurant_locality.append(response["restaurants"][i]["restaurant"]["location"]["locality"])
            restaurant_address.append(response["restaurants"][i]["restaurant"]["location"]["address"])
            restaurant_city.append(response["restaurants"][i]["restaurant"]["location"]["city"])
            latitude.append(response["restaurants"][i]["restaurant"]["location"]["latitude"])
            longitude.append(response["restaurants"][i]["restaurant"]["location"]["longitude"])
            zip_code.append(response["restaurants"][i]["restaurant"]["location"]["zipcode"])
            cuisines.append(response["restaurants"][i]["restaurant"]['cuisines'])
            price_range.append(response["restaurants"][i]["restaurant"]['price_range'])
            average_cost_for_two.append(response["restaurants"][i]["restaurant"]['average_cost_for_two'])
            user_rating.append(response["restaurants"][i]["restaurant"]["user_rating"]['aggregate_rating'])
            rating_text.append(response["restaurants"][i]["restaurant"]["user_rating"]['rating_text'])
            votes.append(response["restaurants"][i]["restaurant"]["user_rating"]['votes'])
            all_reviews_count.append(response["restaurants"][i]["restaurant"]["all_reviews_count"])
        except KeyError:
            print(f"restaurant not found! Skipping")
            pass
    
print("---------------------------")
print("Data Retrieval Complete")

#Convert Raw data to DataFrame

brisbane_df = pd.DataFrame({
    'Restaurant_id': restaurant_id,
    'Name': restaurant_name,
    'Locality':restaurant_locality,
    'Address':restaurant_address,
    'City': restaurant_city,
    'Latitude': latitude,
    'Longitude': longitude,
    'Zip Code': zip_code,
   'Cuisines' : cuisines,
    'Price Range' :price_range,
    'Average Cost for two' :average_cost_for_two,
    'User Rating' : user_rating,
    'Rating Text' : rating_text,
    "Votes" : votes,
    "all_reviews_count": all_reviews_count
})


#Exporting the DataFrame into a csv
brisbane_df.to_csv('output_data/restaurants_category_10_brisbane.csv')
# Out:
# ---------------------------
# Data Retrieval Complete

# %%
#Perth data

p = Pyzomato(z_key)

# set up other lists to hold data info
restaurant_name = []
restaurant_id = []
restaurant_address = []
restaurant_locality = []
restaurant_city = []
latitude = []
longitude = []
zip_code = []
cuisines = []
price_range = []
average_cost_for_two = []
user_rating = []
rating_text = []
votes = []
all_reviews_count = []

#Set up a dictionary with the latitude and longitude of the five cities we are interested in:
#cities = {
 #   "city" : ['Sydney',"Melbourne",'Brisbane','Perth','Adelaide'],
 #   'lat' : ["-33.8688", "-37.8136", "-27.4698", "-31.9505", "-34.9285"],
 #   'lon' : ["151.2094", "144.9631","153.0251", "115.8605", "138.6007"] 
#}

#Data for 100 top restaurants in Perth - Category =10  - dinner:

# Create a loop that iterates five times starting from 0th record and increases by increments of 20
for a in range(0,100,20):
    response = p.search(lat="-31.9505",lon="115.8605",
                           count=20,
                           sort='rating',
                           order='desc',
                           category=(10),
                           start=a)
    for i in range(0,20,1):
        try:
            restaurant_id.append(response["restaurants"][i]["restaurant"]['id'])
            restaurant_name.append(response["restaurants"][i]["restaurant"]['name'])
            restaurant_locality.append(response["restaurants"][i]["restaurant"]["location"]["locality"])
            restaurant_address.append(response["restaurants"][i]["restaurant"]["location"]["address"])
            restaurant_city.append(response["restaurants"][i]["restaurant"]["location"]["city"])
            latitude.append(response["restaurants"][i]["restaurant"]["location"]["latitude"])
            longitude.append(response["restaurants"][i]["restaurant"]["location"]["longitude"])
            zip_code.append(response["restaurants"][i]["restaurant"]["location"]["zipcode"])
            cuisines.append(response["restaurants"][i]["restaurant"]['cuisines'])
            price_range.append(response["restaurants"][i]["restaurant"]['price_range'])
            average_cost_for_two.append(response["restaurants"][i]["restaurant"]['average_cost_for_two'])
            user_rating.append(response["restaurants"][i]["restaurant"]["user_rating"]['aggregate_rating'])
            rating_text.append(response["restaurants"][i]["restaurant"]["user_rating"]['rating_text'])
            votes.append(response["restaurants"][i]["restaurant"]["user_rating"]['votes'])
            all_reviews_count.append(response["restaurants"][i]["restaurant"]["all_reviews_count"])
        except KeyError:
            print(f"restaurant not found! Skipping")
            pass
    
print("---------------------------")
print("Data Retrieval Complete")

#Convert Raw data to DataFrame

perth_df = pd.DataFrame({
    'Restaurant_id': restaurant_id,
    'Name': restaurant_name,
    'Locality':restaurant_locality,
    'Address':restaurant_address,
    'City': restaurant_city,
    'Latitude': latitude,
    'Longitude': longitude,
    'Zip Code': zip_code,
   'Cuisines' : cuisines,
    'Price Range' :price_range,
    'Average Cost for two' :average_cost_for_two,
    'User Rating' : user_rating,
    'Rating Text' : rating_text,
    "Votes" : votes,
    "all_reviews_count": all_reviews_count
})


#Exporting the DataFrame into a csv
perth_df.to_csv('output_data/restaurants_category_10_perth.csv')
# Out:
# ---------------------------
# Data Retrieval Complete

# %%
#Adelaide data

p = Pyzomato(z_key)

# set up other lists to hold data info
restaurant_name = []
restaurant_id = []
restaurant_address = []
restaurant_locality = []
restaurant_city = []
latitude = []
longitude = []
zip_code = []
cuisines = []
price_range = []
average_cost_for_two = []
user_rating = []
rating_text = []
votes = []
all_reviews_count = []

#Set up a dictionary with the latitude and longitude of the five cities we are interested in:
#cities = {
 #   "city" : ['Sydney',"Melbourne",'Brisbane','Perth','Adelaide'],
 #   'lat' : ["-33.8688", "-37.8136", "-27.4698", "-31.9505", "-34.9285"],
 #   'lon' : ["151.2094", "144.9631","153.0251", "115.8605", "138.6007"] 
#}

#Data for 100 top restaurants in Perth - Category =10  - dinner:

# Create a loop that iterates five times starting from 0th record and increases by increments of 20
for a in range(0,100,20):
    response = p.search(lat="-34.9285",lon="138.6007",
                           count=20,
                           sort='rating',
                           order='desc',
                           category=(10),
                           start=a)
    for i in range(0,20,1):
        try:
            restaurant_id.append(response["restaurants"][i]["restaurant"]['id'])
            restaurant_name.append(response["restaurants"][i]["restaurant"]['name'])
            restaurant_locality.append(response["restaurants"][i]["restaurant"]["location"]["locality"])
            restaurant_address.append(response["restaurants"][i]["restaurant"]["location"]["address"])
            restaurant_city.append(response["restaurants"][i]["restaurant"]["location"]["city"])
            latitude.append(response["restaurants"][i]["restaurant"]["location"]["latitude"])
            longitude.append(response["restaurants"][i]["restaurant"]["location"]["longitude"])
            zip_code.append(response["restaurants"][i]["restaurant"]["location"]["zipcode"])
            cuisines.append(response["restaurants"][i]["restaurant"]['cuisines'])
            price_range.append(response["restaurants"][i]["restaurant"]['price_range'])
            average_cost_for_two.append(response["restaurants"][i]["restaurant"]['average_cost_for_two'])
            user_rating.append(response["restaurants"][i]["restaurant"]["user_rating"]['aggregate_rating'])
            rating_text.append(response["restaurants"][i]["restaurant"]["user_rating"]['rating_text'])
            votes.append(response["restaurants"][i]["restaurant"]["user_rating"]['votes'])
            all_reviews_count.append(response["restaurants"][i]["restaurant"]["all_reviews_count"])
        except KeyError:
            print(f"restaurant not found! Skipping")
            pass
    
print("---------------------------")
print("Data Retrieval Complete")

#Convert Raw data to DataFrame

adelaide_df = pd.DataFrame({
    'Restaurant_id': restaurant_id,
    'Name': restaurant_name,
    'Locality':restaurant_locality,
    'Address':restaurant_address,
    'City': restaurant_city,
    'Latitude': latitude,
    'Longitude': longitude,
    'Zip Code': zip_code,
   'Cuisines' : cuisines,
    'Price Range' :price_range,
    'Average Cost for two' :average_cost_for_two,
    'User Rating' : user_rating,
    'Rating Text' : rating_text,
    "Votes" : votes,
    "all_reviews_count": all_reviews_count
})

#Exporting the DataFrame into a csv
adelaide_df.to_csv('output_data/restaurants_category_10_adelaide.csv')
# Out:
# ---------------------------
# Data Retrieval Complete

# %%
#Concatenate the five dataframes into one called "master"

frames = [sydney_df, melbourne_df, brisbane_df, perth_df, adelaide_df]

master = pd.concat(frames)
master.to_csv('output_data/restaurants_category_10_five_cities.csv')
master.head()
# Out:
#   Restaurant_id               Name       Locality  \
# 0      15547004  Restaurant Hubert            CBD
# 1      16558798               Quay  Circular Quay
# 2      16559171          Tetsuya's            CBD
# 3      16569454  LuMi Bar & Dining        Pyrmont
# 4      15545439            Manpuku      Chatswood
#
#                                              Address    City        Latitude  \
# 0                       15 Bligh Street, CBD, Sydney  Sydney  -33.8653483310
# 1  Upper Level, Overseas Passenger Terminal 5 Hic...  Sydney  -33.8580292558
# 2                       529 Kent Street, CBD, Sydney  Sydney  -33.8751428662
# 3        56 Pirrama Road, \tPyrmont, Pyrmont, Sydney  Sydney  -33.8671367304
# 4             226 Victoria Avenue, Chatswood, Sydney  Sydney  -33.7944174758
#
#         Longitude Zip Code           Cuisines  Price Range  \
# 0  151.2106238678     2000   French, European            4
# 1  151.2099704146     2000  Modern Australian            4
# 2  151.2049315497                    Japanese            4
# 3  151.1975169182     2009  Italian, Japanese            4
# 4  151.1895420402     2067    Japanese, Ramen            2
#
#    Average Cost for two User Rating Rating Text  Votes  all_reviews_count
# 0                   150         4.9   Excellent    590                224
# 1                   500         4.9   Excellent   1366                454
# 2                   440         4.9   Excellent   1234                329
# 3                   190         4.9   Excellent    452                196
# 4                    40         4.9   Excellent    486                190
